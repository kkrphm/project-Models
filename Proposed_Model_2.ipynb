# %% [markdown]
# <a href="https://colab.research.google.com/github/kkrphm/project-Models/blob/main/Proposed_Model_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Connect to Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Import Libraries**

# %%
# For Data Processing
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tensorflow.keras.utils  import to_categorical
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, f1_score,roc_auc_score, classification_report,roc_curve,auc
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.image import img_to_array,ImageDataGenerator, load_img
from keras.utils import np_utils
from tensorflow.keras.utils  import to_categorical
from numpy import expand_dims
from sklearn.preprocessing import LabelBinarizer

# For DL Models
import tensorflow as tf
from tensorflow import keras
from keras import layers, regularizers
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, GlobalAveragePooling2D,BatchNormalization,LayerNormalization, Conv2D, MaxPooling2D, ZeroPadding2D
from keras.models import Model,load_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.losses import *
from keras.applications import *

# For Data Visualization
import seaborn as sns
import cv2
import plotly.graph_objs as go
from plotly import tools
# %matplotlib inline
import matplotlib.pyplot as plt #used for plotting and analyzing data
import matplotlib
andy_theme = {'axes.grid': True,
              'grid.linestyle': '--',
              'legend.framealpha': 1,
              'legend.facecolor': 'white',
              'legend.shadow': True,
              'legend.fontsize': 14,
              'legend.title_fontsize': 16,
              'xtick.labelsize': 14,
              'ytick.labelsize': 14,
              'axes.labelsize': 16,
              'axes.titlesize': 20,
              'axes.linewidth':'1',
              'axes.edgecolor':'0',
              'figure.dpi': 600
               }

# Miscellaneous       
import random
import warnings
warnings.filterwarnings("ignore")
import os #file I/O

# %% [markdown]
# ## **Training & Validation Datasets**

# %%
train_data_dir = '/content/drive/MyDrive/Project (1)/Brain_Tumor/Training' #data is already in colab file
validation_data_dir = '/content/drive/MyDrive/Project (1)/Brain_Tumor/Testing'
test_data_dir='/content/drive/MyDrive/Project (1)/Brain_Tumor/Testing'
Model_File_path='/content/drive/MyDrive/6-model/'
nb_train_samples =5722
nb_validation_samples =1311
nb_test_samples =153
epochs = 15
batch_size = 32
num_classes=4
seed=123
# input image dimensions
img_rows, img_cols = 512,512
input_shape = (img_rows, img_cols, 3)
IMG_HEIGHT = 512
IMG_WIDTH = 512

# %% [markdown]
# # **Data Augmentation**

# %%
# using the ImageDataGenerator to prepare the images (Resize, nomalize, etc)

train_generator = ImageDataGenerator(rescale=1./255,
                                    featurewise_center=False,
                                    samplewise_center=False,
                                    featurewise_std_normalization=False,
                                    samplewise_std_normalization=False,
                                    zca_whitening=False,
                                    rotation_range=0,
                                    zoom_range = 0.2,
                                    shear_range=0.2,
                                    width_shift_range=0,
                                    height_shift_range=0,
                                    horizontal_flip=True,
                                    vertical_flip=True,
                                    fill_mode="nearest") 
 

  
val_generator = ImageDataGenerator(rescale=1./255,
                                    featurewise_center=False,
                                    samplewise_center=False,
                                    featurewise_std_normalization=False,
                                    samplewise_std_normalization=False,
                                    zca_whitening=False,
                                    rotation_range=0,
                                    zoom_range = 0.2,
                                    shear_range=0.2,
                                    width_shift_range=0,
                                    height_shift_range=0,
                                    horizontal_flip=True,
                                    vertical_flip=True,
                                    fill_mode="nearest")

test_generator = ImageDataGenerator(rescale=1. / 255)

# %%
# Creating the train and test data.

train = train_generator.flow_from_directory(train_data_dir, target_size=(64,64),
                                              batch_size=64, class_mode= "categorical", color_mode='grayscale')

valadition = val_generator.flow_from_directory(validation_data_dir, target_size=(64,64),
                                              batch_size=64, class_mode= "categorical", color_mode='grayscale')

test = test_generator.flow_from_directory(test_data_dir, target_size=(64,64),
                                              shuffle=False,batch_size=64, class_mode= "categorical", color_mode='grayscale')
# Out:
# Found 5712 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.

# %% [markdown]
# # **Let's visualize the data.**

# %%
index = ['glioma','meningioma','notumor','pituitary']
trained_classes=[]
for i in train.classes:
  trained_classes.append(index[i])
print(trained_classes[:5])
test_classes=[]
for i in test.classes:
  test_classes.append(index[i])
print(test_classes[:5])
# Out:
# ['glioma', 'glioma', 'glioma', 'glioma', 'glioma']
# ['glioma', 'glioma', 'glioma', 'glioma', 'glioma']

# %%
plt.figure(figsize=(14,6))
colors = ['#4285f4', '#ea4335', '#fbbc05', '#34a853']
plt.rcParams.update({'font.size': 14})
plt.pie([len([x for x in trained_classes if x=='pituitary']),
         len([x for x in trained_classes if x=='notumor']),
         len([x for x in trained_classes if x=='meningioma']),
         len([x for x in trained_classes if x=='glioma'])],
        labels=['pituitary','notumor', 'meningioma', 'glioma'],
        colors=colors, autopct='%.1f%%', explode=(0.025,0.025,0.025,0.025),
        startangle=30);

# %%
plt.figure(figsize=(14,6))
colors = ['#4285f4', '#ea4335', '#fbbc05', '#34a853']
plt.rcParams.update({'font.size': 14})
plt.pie([len(trained_classes), len(test_classes)],
        labels=['Train','Test'],
        colors=colors, autopct='%.1f%%', explode=(0.05,0),
        startangle=30);

# %% [markdown]
# #### **Ploting a image of each brain tumor type**

# %%
plt.figure(figsize=(20, 16))

images_path = ['/glioma/Tr-glTr_0000.jpg', '/meningioma/Tr-meTr_0000.jpg', '/notumor/Tr-noTr_0000.jpg', '/pituitary/Tr-piTr_0000.jpg']

for i in range(4):
    ax = plt.subplot(2, 2, i + 1)
    # plt.grid()
    img = cv2.imread(train_data_dir + images_path[i])
    img = cv2.resize(img, (250, 250))
    plt.imshow(img)
    plt.axis('off')
    plt.title(list(train.class_indices.keys())[i])

# %% [markdown]
# # **Modelling**

# %% [markdown]
# # **CNN - Model 1**

# %%
# 96.95%

model1 = Sequential()

# Convolutional layer 1
model1.add(Conv2D(32,(3,3), input_shape=(64, 64, 1), activation='relu'))
model1.add(BatchNormalization())
model1.add(MaxPooling2D(pool_size=(2,2)))

# Convolutional layer 2
model1.add(Conv2D(32,(3,3), activation='relu'))
model1.add(BatchNormalization())
model1.add(MaxPooling2D(pool_size=(2,2)))

model1.add(Flatten())

# Neural network

model1.add(Dense(units= 252, activation='relu'))
model1.add(Dropout(0.2))
model1.add(Dense(units=252, activation='relu'))
model1.add(Dropout(0.2))
model1.add(Dense(units=4, activation='softmax'))

model1.summary()

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, decay=0.0001, clipvalue=0.5)
model1.compile(optimizer=optimizer, loss='categorical_crossentropy',
                   metrics= ['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        320
#
#  batch_normalization (BatchN  (None, 62, 62, 32)       128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 29, 29, 32)       128
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 252)               1580796
#
#  dropout (Dropout)           (None, 252)               0
#
#  dense_1 (Dense)             (None, 252)               63756
#
#  dropout_1 (Dropout)         (None, 252)               0
#
#  dense_2 (Dense)             (None, 4)                 1012
#
# =================================================================
# Total params: 1,655,388
# Trainable params: 1,655,260
# Non-trainable params: 128
# _________________________________________________________________

# %% [markdown]
# #**Trainig model 1**

# %%
# Creating callbacks for the model.
# If the model dosen't continue to improve (loss), the trainning will stop.

# Stop training if loss doesn't keep decreasing.
model1_es = EarlyStopping(monitor = 'loss', min_delta = 1e-11, patience = 12, verbose = 1)
model1_rlr = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, patience = 6, verbose = 1)

# Automatically saves the best weights of the model, based on best val_accuracy
model1_mcp = ModelCheckpoint(filepath = Model_File_path+'model1_weights.h5', monitor = 'val_accuracy', 
                      save_best_only = True, verbose = 1)
batch_size=64
# Fiting the model.
history1 = model1.fit(train, steps_per_epoch=nb_train_samples//batch_size, epochs=100, validation_data=valadition, validation_steps= nb_validation_samples//batch_size,
                     callbacks=[model1_es, model1_rlr, model1_mcp])
# Out:
# Epoch 1/100
# 89/89 [==============================] - ETA: 0s - loss: 1.1112 - accuracy: 0.6087
# Epoch 1: val_accuracy improved from -inf to 0.30781, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 2806s 31s/step - loss: 1.1112 - accuracy: 0.6087 - val_loss: 2.8127 - val_accuracy: 0.3078 - lr: 0.0010
# Epoch 2/100
# 89/89 [==============================] - ETA: 0s - loss: 0.7604 - accuracy: 0.7043
# Epoch 2: val_accuracy did not improve from 0.30781
# 89/89 [==============================] - 27s 302ms/step - loss: 0.7604 - accuracy: 0.7043 - val_loss: 3.8479 - val_accuracy: 0.2320 - lr: 0.0010
# Epoch 3/100
# 89/89 [==============================] - ETA: 0s - loss: 0.6643 - accuracy: 0.7450
# Epoch 3: val_accuracy did not improve from 0.30781
# 89/89 [==============================] - 27s 301ms/step - loss: 0.6643 - accuracy: 0.7450 - val_loss: 3.0845 - val_accuracy: 0.2531 - lr: 0.0010
# Epoch 4/100
# 89/89 [==============================] - ETA: 0s - loss: 0.5765 - accuracy: 0.7771
# Epoch 4: val_accuracy did not improve from 0.30781
# 89/89 [==============================] - 28s 312ms/step - loss: 0.5765 - accuracy: 0.7771 - val_loss: 3.9316 - val_accuracy: 0.2820 - lr: 0.0010
# Epoch 5/100
# 89/89 [==============================] - ETA: 0s - loss: 0.5280 - accuracy: 0.8031
# Epoch 5: val_accuracy improved from 0.30781 to 0.44141, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 27s 308ms/step - loss: 0.5280 - accuracy: 0.8031 - val_loss: 1.9057 - val_accuracy: 0.4414 - lr: 0.0010
# Epoch 6/100
# 89/89 [==============================] - ETA: 0s - loss: 0.4793 - accuracy: 0.8206
# Epoch 6: val_accuracy improved from 0.44141 to 0.50234, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 28s 310ms/step - loss: 0.4793 - accuracy: 0.8206 - val_loss: 1.8336 - val_accuracy: 0.5023 - lr: 0.0010
# Epoch 7/100
# 89/89 [==============================] - ETA: 0s - loss: 0.4225 - accuracy: 0.8378
# Epoch 7: val_accuracy improved from 0.50234 to 0.63516, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 28s 312ms/step - loss: 0.4225 - accuracy: 0.8378 - val_loss: 1.0982 - val_accuracy: 0.6352 - lr: 0.0010
# Epoch 8/100
# 89/89 [==============================] - ETA: 0s - loss: 0.3608 - accuracy: 0.8626
# Epoch 8: val_accuracy improved from 0.63516 to 0.66875, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 28s 313ms/step - loss: 0.3608 - accuracy: 0.8626 - val_loss: 1.0525 - val_accuracy: 0.6687 - lr: 0.0010
# Epoch 9/100
# 89/89 [==============================] - ETA: 0s - loss: 0.3537 - accuracy: 0.8695
# Epoch 9: val_accuracy improved from 0.66875 to 0.72734, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 29s 331ms/step - loss: 0.3537 - accuracy: 0.8695 - val_loss: 0.8067 - val_accuracy: 0.7273 - lr: 0.0010
# Epoch 10/100
# 89/89 [==============================] - ETA: 0s - loss: 0.3418 - accuracy: 0.8637
# Epoch 10: val_accuracy improved from 0.72734 to 0.83203, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 27s 309ms/step - loss: 0.3418 - accuracy: 0.8637 - val_loss: 0.4050 - val_accuracy: 0.8320 - lr: 0.0010
# Epoch 11/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2958 - accuracy: 0.8886
# Epoch 11: val_accuracy improved from 0.83203 to 0.86328, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 27s 307ms/step - loss: 0.2958 - accuracy: 0.8886 - val_loss: 0.3264 - val_accuracy: 0.8633 - lr: 0.0010
# Epoch 12/100
# 89/89 [==============================] - ETA: 0s - loss: 0.3003 - accuracy: 0.8869
# Epoch 12: val_accuracy did not improve from 0.86328
# 89/89 [==============================] - 27s 301ms/step - loss: 0.3003 - accuracy: 0.8869 - val_loss: 0.6640 - val_accuracy: 0.7664 - lr: 0.0010
# Epoch 13/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2662 - accuracy: 0.9003
# Epoch 13: val_accuracy improved from 0.86328 to 0.89141, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 29s 324ms/step - loss: 0.2662 - accuracy: 0.9003 - val_loss: 0.2725 - val_accuracy: 0.8914 - lr: 0.0010
# Epoch 14/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2868 - accuracy: 0.8957
# Epoch 14: val_accuracy did not improve from 0.89141
# 89/89 [==============================] - 27s 305ms/step - loss: 0.2868 - accuracy: 0.8957 - val_loss: 0.2961 - val_accuracy: 0.8844 - lr: 0.0010
# Epoch 15/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2293 - accuracy: 0.9154
# Epoch 15: val_accuracy did not improve from 0.89141
# 89/89 [==============================] - 27s 305ms/step - loss: 0.2293 - accuracy: 0.9154 - val_loss: 0.6427 - val_accuracy: 0.7609 - lr: 0.0010
# Epoch 16/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2324 - accuracy: 0.9140
# Epoch 16: val_accuracy did not improve from 0.89141
# 89/89 [==============================] - 27s 308ms/step - loss: 0.2324 - accuracy: 0.9140 - val_loss: 0.3930 - val_accuracy: 0.8539 - lr: 0.0010
# Epoch 17/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2244 - accuracy: 0.9173
# Epoch 17: val_accuracy improved from 0.89141 to 0.90859, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 28s 311ms/step - loss: 0.2244 - accuracy: 0.9173 - val_loss: 0.2229 - val_accuracy: 0.9086 - lr: 0.0010
# Epoch 18/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2048 - accuracy: 0.9230
# Epoch 18: val_accuracy did not improve from 0.90859
# 89/89 [==============================] - 27s 307ms/step - loss: 0.2048 - accuracy: 0.9230 - val_loss: 0.2447 - val_accuracy: 0.9070 - lr: 0.0010
# Epoch 19/100
# 89/89 [==============================] - ETA: 0s - loss: 0.2157 - accuracy: 0.9189
# Epoch 19: val_accuracy did not improve from 0.90859
# 89/89 [==============================] - 28s 315ms/step - loss: 0.2157 - accuracy: 0.9189 - val_loss: 0.3272 - val_accuracy: 0.8711 - lr: 0.0010
# Epoch 20/100
# 89/89 [==============================] - ETA: 0s - loss: 0.1838 - accuracy: 0.9297
# Epoch 20: val_accuracy improved from 0.90859 to 0.91953, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 28s 310ms/step - loss: 0.1838 - accuracy: 0.9297 - val_loss: 0.2000 - val_accuracy: 0.9195 - lr: 0.0010
# Epoch 21/100
# 89/89 [==============================] - ETA: 0s - loss: 0.1693 - accuracy: 0.9380
# Epoch 21: val_accuracy did not improve from 0.91953
# 89/89 [==============================] - 27s 299ms/step - loss: 0.1693 - accuracy: 0.9380 - val_loss: 0.4203 - val_accuracy: 0.8469 - lr: 0.0010
# Epoch 22/100
# 89/89 [==============================] - ETA: 0s - loss: 0.1767 - accuracy: 0.9352
# Epoch 22: val_accuracy improved from 0.91953 to 0.93125, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 27s 308ms/step - loss: 0.1767 - accuracy: 0.9352 - val_loss: 0.1913 - val_accuracy: 0.9312 - lr: 0.0010
# Epoch 23/100
# 89/89 [==============================] - ETA: 0s - loss: 0.1728 - accuracy: 0.9398
# Epoch 23: val_accuracy did not improve from 0.93125
# 89/89 [==============================] - 27s 302ms/step - loss: 0.1728 - accuracy: 0.9398 - val_loss: 0.2256 - val_accuracy: 0.9156 - lr: 0.0010
# Epoch 24/100
# 89/89 [==============================] - ETA: 0s - loss: 0.1567 - accuracy: 0.9430
# Epoch 24: val_accuracy did not improve from 0.93125
# 89/89 [==============================] - 28s 311ms/step - loss: 0.1567 - accuracy: 0.9430 - val_loss: 0.2362 - val_accuracy: 0.9203 - lr: 0.0010
# Epoch 25/100
# 89/89 [==============================] - ETA: 0s - loss: 0.1539 - accuracy: 0.9481
# Epoch 25: val_accuracy did not improve from 0.93125
# 89/89 [==============================] - 27s 303ms/step - loss: 0.1539 - accuracy: 0.9481 - val_loss: 0.2120 - val_accuracy: 0.9195 - lr: 0.0010
# Epoch 26/100
# 89/89 [==============================] - ETA: 0s - loss: 0.1520 - accuracy: 0.9481
# Epoch 26: val_accuracy did not improve from 0.93125
# 89/89 [==============================] - 27s 305ms/step - loss: 0.1520 - accuracy: 0.9481 - val_loss: 0.2472 - val_accuracy: 0.9078 - lr: 0.0010
# Epoch 27/100
# 89/89 [==============================] - ETA: 0s - loss: 0.1481 - accuracy: 0.9449
# Epoch 27: val_accuracy did not improve from 0.93125
# 89/89 [==============================] - 27s 300ms/step - loss: 0.1481 - accuracy: 0.9449 - val_loss: 0.2445 - val_accuracy: 0.9133 - lr: 0.0010
# Epoch 28/100
# 89/89 [==============================] - ETA: 0s - loss: 0.1410 - accuracy: 0.9456
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 28: val_accuracy did not improve from 0.93125
# 89/89 [==============================] - 27s 301ms/step - loss: 0.1410 - accuracy: 0.9456 - val_loss: 0.2137 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 29/100
# 89/89 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9549
# Epoch 29: val_accuracy improved from 0.93125 to 0.94687, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 27s 307ms/step - loss: 0.1174 - accuracy: 0.9549 - val_loss: 0.1481 - val_accuracy: 0.9469 - lr: 2.0000e-04
# Epoch 30/100
# 89/89 [==============================] - ETA: 0s - loss: 0.1055 - accuracy: 0.9610
# Epoch 30: val_accuracy improved from 0.94687 to 0.96094, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 27s 307ms/step - loss: 0.1055 - accuracy: 0.9610 - val_loss: 0.1074 - val_accuracy: 0.9609 - lr: 2.0000e-04
# Epoch 31/100
# 89/89 [==============================] - ETA: 0s - loss: 0.1029 - accuracy: 0.9623
# Epoch 31: val_accuracy did not improve from 0.96094
# 89/89 [==============================] - 27s 300ms/step - loss: 0.1029 - accuracy: 0.9623 - val_loss: 0.1859 - val_accuracy: 0.9336 - lr: 2.0000e-04
# Epoch 32/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9637
# Epoch 32: val_accuracy did not improve from 0.96094
# 89/89 [==============================] - 27s 300ms/step - loss: 0.0937 - accuracy: 0.9637 - val_loss: 0.1251 - val_accuracy: 0.9484 - lr: 2.0000e-04
# Epoch 33/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0926 - accuracy: 0.9664
# Epoch 33: val_accuracy did not improve from 0.96094
# 89/89 [==============================] - 27s 299ms/step - loss: 0.0926 - accuracy: 0.9664 - val_loss: 0.1224 - val_accuracy: 0.9523 - lr: 2.0000e-04
# Epoch 34/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0808 - accuracy: 0.9729
# Epoch 34: val_accuracy did not improve from 0.96094
# 89/89 [==============================] - 28s 312ms/step - loss: 0.0808 - accuracy: 0.9729 - val_loss: 0.0990 - val_accuracy: 0.9555 - lr: 2.0000e-04
# Epoch 35/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0835 - accuracy: 0.9697
# Epoch 35: val_accuracy did not improve from 0.96094
# 89/89 [==============================] - 27s 305ms/step - loss: 0.0835 - accuracy: 0.9697 - val_loss: 0.1183 - val_accuracy: 0.9516 - lr: 2.0000e-04
# Epoch 36/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9687
# Epoch 36: val_accuracy improved from 0.96094 to 0.96641, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 27s 309ms/step - loss: 0.0853 - accuracy: 0.9687 - val_loss: 0.0945 - val_accuracy: 0.9664 - lr: 2.0000e-04
# Epoch 37/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9740
# Epoch 37: val_accuracy did not improve from 0.96641
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0738 - accuracy: 0.9740 - val_loss: 0.0915 - val_accuracy: 0.9664 - lr: 2.0000e-04
# Epoch 38/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9718
# Epoch 38: val_accuracy did not improve from 0.96641
# 89/89 [==============================] - 27s 300ms/step - loss: 0.0767 - accuracy: 0.9718 - val_loss: 0.1045 - val_accuracy: 0.9578 - lr: 2.0000e-04
# Epoch 39/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0765 - accuracy: 0.9713
# Epoch 39: val_accuracy did not improve from 0.96641
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0765 - accuracy: 0.9713 - val_loss: 0.0954 - val_accuracy: 0.9602 - lr: 2.0000e-04
# Epoch 40/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0654 - accuracy: 0.9759
# Epoch 40: val_accuracy did not improve from 0.96641
# 89/89 [==============================] - 27s 300ms/step - loss: 0.0654 - accuracy: 0.9759 - val_loss: 0.1010 - val_accuracy: 0.9617 - lr: 2.0000e-04
# Epoch 41/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.9738
# Epoch 41: val_accuracy did not improve from 0.96641
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0674 - accuracy: 0.9738 - val_loss: 0.0903 - val_accuracy: 0.9664 - lr: 2.0000e-04
# Epoch 42/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9765
# Epoch 42: val_accuracy did not improve from 0.96641
# 89/89 [==============================] - 27s 306ms/step - loss: 0.0703 - accuracy: 0.9765 - val_loss: 0.0920 - val_accuracy: 0.9656 - lr: 2.0000e-04
# Epoch 43/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9738
# Epoch 43: val_accuracy did not improve from 0.96641
# 89/89 [==============================] - 27s 307ms/step - loss: 0.0738 - accuracy: 0.9738 - val_loss: 0.0900 - val_accuracy: 0.9633 - lr: 2.0000e-04
# Epoch 44/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9780
# Epoch 44: val_accuracy improved from 0.96641 to 0.96797, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 28s 310ms/step - loss: 0.0598 - accuracy: 0.9780 - val_loss: 0.0848 - val_accuracy: 0.9680 - lr: 2.0000e-04
# Epoch 45/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0681 - accuracy: 0.9731
# Epoch 45: val_accuracy did not improve from 0.96797
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0681 - accuracy: 0.9731 - val_loss: 0.1212 - val_accuracy: 0.9547 - lr: 2.0000e-04
# Epoch 46/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0683 - accuracy: 0.9743
# Epoch 46: val_accuracy improved from 0.96797 to 0.97031, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 27s 308ms/step - loss: 0.0683 - accuracy: 0.9743 - val_loss: 0.0835 - val_accuracy: 0.9703 - lr: 2.0000e-04
# Epoch 47/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0705 - accuracy: 0.9749
# Epoch 47: val_accuracy did not improve from 0.97031
# 89/89 [==============================] - 27s 302ms/step - loss: 0.0705 - accuracy: 0.9749 - val_loss: 0.0976 - val_accuracy: 0.9695 - lr: 2.0000e-04
# Epoch 48/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0598 - accuracy: 0.9795
# Epoch 48: val_accuracy did not improve from 0.97031
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0598 - accuracy: 0.9795 - val_loss: 0.0825 - val_accuracy: 0.9664 - lr: 2.0000e-04
# Epoch 49/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9802
# Epoch 49: val_accuracy did not improve from 0.97031
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0569 - accuracy: 0.9802 - val_loss: 0.1036 - val_accuracy: 0.9609 - lr: 2.0000e-04
# Epoch 50/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0553 - accuracy: 0.9791
# Epoch 50: val_accuracy improved from 0.97031 to 0.97188, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 27s 308ms/step - loss: 0.0553 - accuracy: 0.9791 - val_loss: 0.0810 - val_accuracy: 0.9719 - lr: 2.0000e-04
# Epoch 51/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9807
# Epoch 51: val_accuracy did not improve from 0.97188
# 89/89 [==============================] - 27s 302ms/step - loss: 0.0548 - accuracy: 0.9807 - val_loss: 0.0715 - val_accuracy: 0.9719 - lr: 2.0000e-04
# Epoch 52/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0611 - accuracy: 0.9795
# Epoch 52: val_accuracy did not improve from 0.97188
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0611 - accuracy: 0.9795 - val_loss: 0.0848 - val_accuracy: 0.9688 - lr: 2.0000e-04
# Epoch 53/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9795
# Epoch 53: val_accuracy did not improve from 0.97188
# 89/89 [==============================] - 27s 307ms/step - loss: 0.0543 - accuracy: 0.9795 - val_loss: 0.0769 - val_accuracy: 0.9680 - lr: 2.0000e-04
# Epoch 54/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9800
# Epoch 54: val_accuracy did not improve from 0.97188
# 89/89 [==============================] - 27s 300ms/step - loss: 0.0570 - accuracy: 0.9800 - val_loss: 0.0660 - val_accuracy: 0.9711 - lr: 2.0000e-04
# Epoch 55/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0556 - accuracy: 0.9803
# Epoch 55: val_accuracy improved from 0.97188 to 0.97266, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 27s 307ms/step - loss: 0.0556 - accuracy: 0.9803 - val_loss: 0.0704 - val_accuracy: 0.9727 - lr: 2.0000e-04
# Epoch 56/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0533 - accuracy: 0.9795
# Epoch 56: val_accuracy did not improve from 0.97266
# 89/89 [==============================] - 27s 302ms/step - loss: 0.0533 - accuracy: 0.9795 - val_loss: 0.1055 - val_accuracy: 0.9578 - lr: 2.0000e-04
# Epoch 57/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0500 - accuracy: 0.9826
# Epoch 57: val_accuracy did not improve from 0.97266
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0500 - accuracy: 0.9826 - val_loss: 0.1054 - val_accuracy: 0.9578 - lr: 2.0000e-04
# Epoch 58/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 0.9823
# Epoch 58: val_accuracy did not improve from 0.97266
# 89/89 [==============================] - 28s 312ms/step - loss: 0.0522 - accuracy: 0.9823 - val_loss: 0.0785 - val_accuracy: 0.9664 - lr: 2.0000e-04
# Epoch 59/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 0.9802
# Epoch 59: val_accuracy did not improve from 0.97266
# 89/89 [==============================] - 27s 302ms/step - loss: 0.0530 - accuracy: 0.9802 - val_loss: 0.0768 - val_accuracy: 0.9695 - lr: 2.0000e-04
# Epoch 60/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9848
# Epoch 60: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 60: val_accuracy improved from 0.97266 to 0.97656, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 27s 309ms/step - loss: 0.0494 - accuracy: 0.9848 - val_loss: 0.0692 - val_accuracy: 0.9766 - lr: 2.0000e-04
# Epoch 61/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.9835
# Epoch 61: val_accuracy did not improve from 0.97656
# 89/89 [==============================] - 27s 303ms/step - loss: 0.0461 - accuracy: 0.9835 - val_loss: 0.0712 - val_accuracy: 0.9727 - lr: 4.0000e-05
# Epoch 62/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0481 - accuracy: 0.9830
# Epoch 62: val_accuracy improved from 0.97656 to 0.97891, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 27s 307ms/step - loss: 0.0481 - accuracy: 0.9830 - val_loss: 0.0612 - val_accuracy: 0.9789 - lr: 4.0000e-05
# Epoch 63/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9858
# Epoch 63: val_accuracy did not improve from 0.97891
# 89/89 [==============================] - 28s 316ms/step - loss: 0.0418 - accuracy: 0.9858 - val_loss: 0.0574 - val_accuracy: 0.9781 - lr: 4.0000e-05
# Epoch 64/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 0.9855
# Epoch 64: val_accuracy did not improve from 0.97891
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0441 - accuracy: 0.9855 - val_loss: 0.0704 - val_accuracy: 0.9766 - lr: 4.0000e-05
# Epoch 65/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0439 - accuracy: 0.9835
# Epoch 65: val_accuracy did not improve from 0.97891
# 89/89 [==============================] - 27s 302ms/step - loss: 0.0439 - accuracy: 0.9835 - val_loss: 0.0797 - val_accuracy: 0.9711 - lr: 4.0000e-05
# Epoch 66/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 0.9857
# Epoch 66: val_accuracy did not improve from 0.97891
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0441 - accuracy: 0.9857 - val_loss: 0.0690 - val_accuracy: 0.9781 - lr: 4.0000e-05
# Epoch 67/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 0.9837
# Epoch 67: val_accuracy did not improve from 0.97891
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0420 - accuracy: 0.9837 - val_loss: 0.0551 - val_accuracy: 0.9789 - lr: 4.0000e-05
# Epoch 68/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0451 - accuracy: 0.9837
# Epoch 68: val_accuracy improved from 0.97891 to 0.98047, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 27s 307ms/step - loss: 0.0451 - accuracy: 0.9837 - val_loss: 0.0642 - val_accuracy: 0.9805 - lr: 4.0000e-05
# Epoch 69/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9864
# Epoch 69: val_accuracy did not improve from 0.98047
# 89/89 [==============================] - 27s 302ms/step - loss: 0.0397 - accuracy: 0.9864 - val_loss: 0.0732 - val_accuracy: 0.9727 - lr: 4.0000e-05
# Epoch 70/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0441 - accuracy: 0.9834
# Epoch 70: val_accuracy did not improve from 0.98047
# 89/89 [==============================] - 27s 302ms/step - loss: 0.0441 - accuracy: 0.9834 - val_loss: 0.0600 - val_accuracy: 0.9797 - lr: 4.0000e-05
# Epoch 71/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0475 - accuracy: 0.9825
# Epoch 71: val_accuracy did not improve from 0.98047
# 89/89 [==============================] - 27s 302ms/step - loss: 0.0475 - accuracy: 0.9825 - val_loss: 0.0676 - val_accuracy: 0.9789 - lr: 4.0000e-05
# Epoch 72/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9862
# Epoch 72: val_accuracy did not improve from 0.98047
# 89/89 [==============================] - 28s 317ms/step - loss: 0.0397 - accuracy: 0.9862 - val_loss: 0.0569 - val_accuracy: 0.9805 - lr: 4.0000e-05
# Epoch 73/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0424 - accuracy: 0.9846
# Epoch 73: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 73: val_accuracy did not improve from 0.98047
# 89/89 [==============================] - 27s 303ms/step - loss: 0.0424 - accuracy: 0.9846 - val_loss: 0.0683 - val_accuracy: 0.9734 - lr: 4.0000e-05
# Epoch 74/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0432 - accuracy: 0.9848
# Epoch 74: val_accuracy did not improve from 0.98047
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0432 - accuracy: 0.9848 - val_loss: 0.0646 - val_accuracy: 0.9750 - lr: 8.0000e-06
# Epoch 75/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9864
# Epoch 75: val_accuracy did not improve from 0.98047
# 89/89 [==============================] - 27s 302ms/step - loss: 0.0425 - accuracy: 0.9864 - val_loss: 0.0576 - val_accuracy: 0.9758 - lr: 8.0000e-06
# Epoch 76/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0440 - accuracy: 0.9835
# Epoch 76: val_accuracy improved from 0.98047 to 0.98203, saving model to /content/drive/MyDrive/6-model(1-3)/model1_weights.h5
# 89/89 [==============================] - 27s 307ms/step - loss: 0.0440 - accuracy: 0.9835 - val_loss: 0.0570 - val_accuracy: 0.9820 - lr: 8.0000e-06
# Epoch 77/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9835
# Epoch 77: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 28s 312ms/step - loss: 0.0496 - accuracy: 0.9835 - val_loss: 0.0590 - val_accuracy: 0.9758 - lr: 8.0000e-06
# Epoch 78/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9850
# Epoch 78: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0453 - accuracy: 0.9850 - val_loss: 0.0563 - val_accuracy: 0.9781 - lr: 8.0000e-06
# Epoch 79/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9874
# Epoch 79: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 300ms/step - loss: 0.0346 - accuracy: 0.9874 - val_loss: 0.0531 - val_accuracy: 0.9797 - lr: 8.0000e-06
# Epoch 80/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0367 - accuracy: 0.9873
# Epoch 80: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 302ms/step - loss: 0.0367 - accuracy: 0.9873 - val_loss: 0.0632 - val_accuracy: 0.9766 - lr: 8.0000e-06
# Epoch 81/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0418 - accuracy: 0.9853
# Epoch 81: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 28s 318ms/step - loss: 0.0418 - accuracy: 0.9853 - val_loss: 0.0653 - val_accuracy: 0.9820 - lr: 8.0000e-06
# Epoch 82/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0433 - accuracy: 0.9842
# Epoch 82: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 302ms/step - loss: 0.0433 - accuracy: 0.9842 - val_loss: 0.0743 - val_accuracy: 0.9773 - lr: 8.0000e-06
# Epoch 83/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9860
# Epoch 83: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 303ms/step - loss: 0.0380 - accuracy: 0.9860 - val_loss: 0.0594 - val_accuracy: 0.9773 - lr: 8.0000e-06
# Epoch 84/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0341 - accuracy: 0.9880
# Epoch 84: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0341 - accuracy: 0.9880 - val_loss: 0.0518 - val_accuracy: 0.9797 - lr: 8.0000e-06
# Epoch 85/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9858
# Epoch 85: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0371 - accuracy: 0.9858 - val_loss: 0.0517 - val_accuracy: 0.9758 - lr: 8.0000e-06
# Epoch 86/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9851
# Epoch 86: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 28s 313ms/step - loss: 0.0393 - accuracy: 0.9851 - val_loss: 0.0625 - val_accuracy: 0.9773 - lr: 8.0000e-06
# Epoch 87/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0422 - accuracy: 0.9841
# Epoch 87: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0422 - accuracy: 0.9841 - val_loss: 0.0576 - val_accuracy: 0.9820 - lr: 8.0000e-06
# Epoch 88/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9871
# Epoch 88: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 303ms/step - loss: 0.0406 - accuracy: 0.9871 - val_loss: 0.0612 - val_accuracy: 0.9750 - lr: 8.0000e-06
# Epoch 89/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 0.9869
# Epoch 89: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 302ms/step - loss: 0.0384 - accuracy: 0.9869 - val_loss: 0.0616 - val_accuracy: 0.9766 - lr: 8.0000e-06
# Epoch 90/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0383 - accuracy: 0.9865
# Epoch 90: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 302ms/step - loss: 0.0383 - accuracy: 0.9865 - val_loss: 0.0514 - val_accuracy: 0.9789 - lr: 8.0000e-06
# Epoch 91/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0454 - accuracy: 0.9841
# Epoch 91: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 28s 314ms/step - loss: 0.0454 - accuracy: 0.9841 - val_loss: 0.0560 - val_accuracy: 0.9758 - lr: 8.0000e-06
# Epoch 92/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9873
# Epoch 92: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 301ms/step - loss: 0.0401 - accuracy: 0.9873 - val_loss: 0.0681 - val_accuracy: 0.9773 - lr: 8.0000e-06
# Epoch 93/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0388 - accuracy: 0.9858
# Epoch 93: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 305ms/step - loss: 0.0388 - accuracy: 0.9858 - val_loss: 0.0632 - val_accuracy: 0.9773 - lr: 8.0000e-06
# Epoch 94/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9858
# Epoch 94: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 305ms/step - loss: 0.0412 - accuracy: 0.9858 - val_loss: 0.0509 - val_accuracy: 0.9820 - lr: 8.0000e-06
# Epoch 95/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 0.9844
# Epoch 95: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 304ms/step - loss: 0.0466 - accuracy: 0.9844 - val_loss: 0.0674 - val_accuracy: 0.9742 - lr: 8.0000e-06
# Epoch 96/100
# 89/89 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.9857
# Epoch 96: val_accuracy did not improve from 0.98203
# 89/89 [==============================] - 27s 302ms/step - loss: 0.0411 - accuracy: 0.9857 - val_loss: 0.0564 - val_accuracy: 0.9781 - lr: 8.0000e-06
# Epoch 96: early stopping

# %% [markdown]
# # **Model Evaluation**

# %%
model1.evaluate(test)
# Out:
# 21/21 [==============================] - 5s 223ms/step - loss: 0.1154 - accuracy: 0.9649
# [0.11541275680065155, 0.9649122953414917]

# %% [markdown]
# # **Model Save**

# %%
np.save(Model_File_path+'my_history1.npy',history1.history)

# %% [markdown]
# # **Progess of Model accuracy & Loss**

# %%
# %matplotlib inline
acc = history1.history['accuracy']
val_acc = history1.history['val_accuracy']
loss = history1.history['loss']
val_loss = history1.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
# comparing training and testing loss 
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('Loss of the model')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['train','val.'],loc='upper left')
plt.show()

# %% [markdown]
# # **Model Loading**

# %%
model1A=load_model(Model_File_path+'model1_weights.h5')

# %% [markdown]
# # **Model Evaluation**

# %%
A1=model1A.evaluate(test)
A1
# Out:
# 21/21 [==============================] - 193s 10s/step - loss: 0.1189 - accuracy: 0.9619
# [0.11890585720539093, 0.9618611931800842]

# %%
pred_test = model1A.predict(test, verbose=1)
# Out:
# 21/21 [==============================] - 234s 12s/step

# %%
classes=list(train.class_indices.keys())

# %%
predict_labels_Test = pred_test
predict_labels_Test1 = predict_labels_Test
predict_labels=np.argmax(predict_labels_Test, axis=1)
# print(predict_labels)

predict_labels_TestV2_ctg = np_utils.to_categorical(predict_labels, num_classes)
labels_Test_ctg = np_utils.to_categorical(test.classes, num_classes)
predict_labels_Ar = np.asarray(predict_labels)
print("\npredict_labels_Test")
print(f'Numbre of {classes[0]} : {(predict_labels_Ar == 0).sum()}')
print(f'Numbre of {classes[1]} : {(predict_labels_Ar == 1).sum()}')
print(f'Numbre of {classes[2]} : {(predict_labels_Ar == 2).sum()}')
print(f'Numbre of {classes[3]} : {(predict_labels_Ar == 3).sum()}')

print("\n"+classification_report(predict_labels_TestV2_ctg, labels_Test_ctg))

cm = confusion_matrix(predict_labels, test.classes) 
#cm1=np.array([[126, 1, 3], [0,193,9],[0,7,190]])
print('Confusion Matrix')
plt.figure()
ax= plt.subplot()
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.tick_params(which='major', width=1.00)
ax.tick_params(which='major', length=5)
ax.tick_params(which='minor', width=0.75)
ax.tick_params(which='minor', length=2.5)
ax.tick_params(direction='out', length=5, width=2, colors='black',
               grid_color='black', grid_alpha=0.5)
sns.set(font_scale=2)
sns.heatmap(cm, annot= True, fmt='', cmap='GnBu', cbar=True, annot_kws={"size": 16})
labels=classes
plt.rcParams.update(andy_theme)
ax.set_xlabel("\nTrue Labels\n" ,fontweight="bold")
ax.set_ylabel("Predicted Labels\n" ,fontweight="bold")
#ax.set_title('Confusion Matrix of VGG 16 Model',fontweight="bold"); 
ax.xaxis.set_ticklabels(labels,fontweight="bold", rotation = 90,); 
ax.yaxis.set_ticklabels(labels,fontweight="bold", rotation = 0,);

plt.show()
# Out:
# predict_labels_Test
# Numbre of glioma : 277
# Numbre of meningioma : 297
# Numbre of notumor : 432
# Numbre of pituitary : 305
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       277
#            1       0.92      0.95      0.94       297
#            2       1.00      0.94      0.97       432
#            3       1.00      0.98      0.99       305
#
#    micro avg       0.96      0.96      0.96      1311
#    macro avg       0.96      0.96      0.96      1311
# weighted avg       0.96      0.96      0.96      1311
#  samples avg       0.96      0.96      0.96      1311
#
# Confusion Matrix

# %%
test_classes=to_categorical(test.classes)

# %%
Accuracy=accuracy_score(test.classes,predict_labels)
Accuracy
# Out:
# 0.96186117467582

# %% [markdown]
# # **ROC_AUC Curve**

# %%
AUC=roc_auc_score(test_classes,pred_test)
AUC
# Out:
# 0.997704351784781

# %%
target= list(test.class_indices.keys())

# set plot figure size
fig, c_ax = plt.subplots(1,1, figsize = (12, 8))

# function for scoring roc auc score for multi-class
def multiclass_roc_auc_score(y_test, y_pred, average="macro"):
    lb = LabelBinarizer()
    lb.fit(y_test)
    y_test = lb.transform(y_test)
    y_pred = lb.transform(y_pred)

    for (idx, c_label) in enumerate(target):
        fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
        c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
    c_ax.plot(fpr, fpr, 'b-', linestyle='--',label = 'Random Guessing')
    return roc_auc_score(y_test, y_pred, average=average)


print('ROC AUC score:', multiclass_roc_auc_score(test.classes,predict_labels))

c_ax.legend()
c_ax.set_xlabel('False Positive Rate')
c_ax.set_ylabel('True Positive Rate')
plt.show()
# Out:
# ROC AUC score: 0.9727753564242295

# %% [markdown]
# # **Model Testing**

# %%
test = test_generator.flow_from_directory(test_data_dir, 
                                          target_size=(512,512),
                                          shuffle=True,
                                          batch_size=64, 
                                          class_mode= "sparse",
                                          color_mode='grayscale')
# Out:
# Found 1311 images belonging to 4 classes.

# %%
class_names=['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
images, labels = next(test)
plt.figure(figsize=(20, 20))
for i in range(16):
        ax = plt.subplot(4, 4, i + 1)
        image = cv2.resize(images[i], (512,512))
        plt.imshow(image)
        plt.grid()
        image = cv2.resize(images[i], (64,64))
        image = tf.keras.utils.img_to_array(image)
        # img_array = tf.expand_dims(img_array, 0) # Create a batch
        predictions = model1A.predict(tf.expand_dims(image, 0))
        score = tf.nn.softmax(predictions[0])
        if(class_names[int(labels[i])]==class_names[np.argmax(score)]):
            plt.title("Actual: "+ class_names[int(labels[i])],fontsize=16)
            plt.xlabel("Predicted: "+ class_names[np.argmax(score)],fontsize=16,fontdict={'color':'green'})
            
        else:
            plt.title("Actual: "+ class_names[int(labels[i])],fontsize=16)
            plt.xlabel("Predicted: "+ class_names[np.argmax(score)],fontsize=16, fontdict={'color':'red'})
        plt.gca().axes.yaxis.set_ticklabels([])        
        plt.gca().axes.xaxis.set_ticklabels([])
